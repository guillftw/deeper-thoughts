# %%
def minion_game(string):
    vowels = 'AEIOU'
    
    # Stuart plays
    stuart_point = 0
    
    multiplier = len(string)
    
    for i in range(len(string)):
        if string[i] not in vowels:
            stuart_point = stuart_point + multiplier
            # print(substring)
        else:
            pass
        multiplier = multiplier - 1
        
    # Kevin plays
    kevin_point = 0
    
    multiplier = len(string)
    
    for i in range(len(string)):
        if string[i] in vowels:
            kevin_point = kevin_point + multiplier
            # print(substring)
        else:
            pass
        multiplier = multiplier - 1
    
    # Winner setting

    if stuart_point > kevin_point:
        print("Stuart " + str(stuart_point))
    elif kevin_point > stuart_point:
        print("Kevin " + str(kevin_point))
    else:
        print("Draw")

# %%
minion_game('...')
# Out:
# Stuart 50005000
